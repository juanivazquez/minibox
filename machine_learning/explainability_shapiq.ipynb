# %%
# 📘 Notebook Title

This notebook provides a simple and practical implementation of [SHAPIQ] for [Explainability]. It includes minimal setup, step-by-step examples, and key insights to help understand and apply the concept efficiently.

# %% [markdown]
# https://github.com/mmschlk/shapiq

# %%
# pip install shapiq
# pip install git+https://github.com/mmschlk/shapiq

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import shapiq

shapiq.__version__
# Out:
# '0.0.1'

# %%
from sklearn.datasets import fetch_california_housing
X,y = pd.DataFrame(housing['data'],columns=housing['feature_names']),pd.DataFrame(housing['target'],columns=housing['target_names'])
# housing = fetch_california_housing()
# X, y = shapiq.load_california_housing()
X_train, X_test, y_train, y_test = train_test_split(
    X.values, y.values, test_size=0.25, random_state=42
)
n_features = X_train.shape[1]

# %%
model = RandomForestRegressor(
    n_estimators=500, max_depth=n_features, max_features=2 / 3, max_samples=2 / 3, random_state=42
)
model.fit(X_train, y_train)
print("Train R2: {:.4f}".format(model.score(X_train, y_train)))
print("Test  R2: {:.4f}".format(model.score(X_test, y_test)))
# Out:
# c:\Users\juani\anaconda3\envs\time_series\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Train R2: 0.7991
# Test  R2: 0.7462

# %%
explainer_tabular = shapiq.TabularExplainer(model=model, data=X_train, index="SII", max_order=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 explainer_tabular = shapiq.TabularExplainer(model=model, data=X_train, index="SII", max_order=2)
#
# AttributeError: module 'shapiq' has no attribute 'TabularExplainer'

# %%
x = X_test[24]

# %%
interaction_values = explainer_tabular.explain(x, budget=2**n_features, random_state=0)
interaction_values

# %%
# This library is still WIP and not working properly... modules not found. etc.
