# %% [markdown]
# # Ex. 1 | **datos.gob.ar**
# ### GEC0319 | JIVB | Time Series

# %% [markdown]
# ## Settings

# %% [markdown]
# Armar una función wrapper que facilite construir llamadas a la API.

# %%
pip install tswidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 37.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 57.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.5/821.5 kB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 67.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 71.0.4
#     Uninstalling setuptools-71.0.4:
#       Successfully uninstalled setuptools-71.0.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
# ...

# %%
from tswidgets import sdt_get

# %%
api_call = sdt_get(["168.1_T_CAMBIOR_D_0_0_26"], start_date="2018-08")
api_call.head()
# Out:
#                tipo_cambio_bna_vendedor
# indice_tiempo
# 2018-08-01                         28.6
# 2018-08-02                         28.6
# 2018-08-03                         28.6
# 2018-08-04                         28.6
# 2018-08-05                         28.6

# %% [markdown]
# Obtener la respuesta en un diccionario.

# %%
api_call = sdt_get(['43.2_ECTATN_0_T_41'], start_date="2018-08")
api_call.head()
# Out:
#                eph_continua_tasa_actividad_total_neuquen
# indice_tiempo
# 2018-10-01                                         0.441
# 2019-01-01                                         0.449
# 2019-04-01                                         0.483
# 2019-07-01                                         0.463
# 2019-10-01                                         0.457
