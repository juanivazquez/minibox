# %% [markdown]
# ## # Exp. 4 | **TSWIDGETS**
# ### GEC0319 | JIVB | Time Series
# - Experiment N° **4**

# %% [markdown]
# ## Settings

# %%
pip install tswidgets --upgrade
# Out:
# Requirement already satisfied: tswidgets in /usr/local/lib/python3.11/dist-packages (0.0.2)
# Requirement already satisfied: matplotlib==3.7.5 in /usr/local/lib/python3.11/dist-packages (from tswidgets) (3.7.5)
# Requirement already satisfied: numpy==1.24.4 in /usr/local/lib/python3.11/dist-packages (from tswidgets) (1.24.4)
# Requirement already satisfied: pandas==2.0.3 in /usr/local/lib/python3.11/dist-packages (from tswidgets) (2.0.3)
# Requirement already satisfied: Requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from tswidgets) (2.32.3)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.11/dist-packages (from tswidgets) (0.13.2)
# Requirement already satisfied: setuptools==69.2.0 in /usr/local/lib/python3.11/dist-packages (from tswidgets) (69.2.0)
# Requirement already satisfied: statsmodels==0.14.1 in /usr/local/lib/python3.11/dist-packages (from tswidgets) (0.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.5->tswidgets) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.5->tswidgets) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.5->tswidgets) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.5->tswidgets) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.5->tswidgets) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.5->tswidgets) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.5->tswidgets) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.5->tswidgets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.3->tswidgets) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.0.3->tswidgets) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from Requests==2.32.3->tswidgets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from Requests==2.32.3->tswidgets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from Requests==2.32.3->tswidgets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from Requests==2.32.3->tswidgets) (2025.1.31)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels==0.14.1->tswidgets) (1.14.1)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels==0.14.1->tswidgets) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.5->tswidgets) (1.17.0)

# %%
import tswidgets

# %%
# Check the datasets directory
import os
datasets_dir = os.path.join(tswidgets.__path__[0], 'datasets')
print("Datasets directory:", datasets_dir)
print("Available datasets:", os.listdir(datasets_dir))
# Out:
# Datasets directory: /usr/local/lib/python3.11/dist-packages/tswidgets/datasets
# Available datasets: ['load_dataset.py', 'hyndman.pkl', '__pycache__', 'levendis.pkl', 'enders.pkl', '__init__.py']

# %% [markdown]
# # Tutorial

# %%
import tswidgets

# %%
from tswidgets import load_dataset

# %%
levendis = load_dataset('levendis')
hyndman = load_dataset('hyndman')
enders = load_dataset('enders')

# %%
levendis.keys()
# Out:
# dict_keys(['AR1nonzero_b', 'arch-1', 'ARCH-F', 'ARCH-GM', 'ARCH-TM', 'ARexample', 'ARIMA_DJI', 'ARMAexample', 'ARMAexercise', 'Bollerslev1987', 'BollerslevSP', 'h1data', 'CPI', 'DandL', 'DJIA', 'DTdata', 'EG_ex_C_Y', 'GARCH-IBM', 'GARCH-M example', 'gdppcap', 'GOOG', 'IGARCH-DJIA', 'Index', 'integrated012', 'MAexample', 'NelsonPlosserData', 'PCEC_GDP', 'rGDPgr', 'RWdata', 'easonal_data', 'easonal_unemp_rate', 'tationarity_ex', 'VAR_sim'])

# %%
nelson_plosser = levendis['NelsonPlosserData']
nelson_plosser.head()
# Out:
#       rgnp  gnp  pcrgnp   ip  emp  un  prgnp   cpi  wg  rwg  ...       lip  \
# year                                                         ...
# 1860   NaN  NaN     NaN  0.9  NaN NaN    NaN  27.0 NaN  NaN  ... -0.105361
# 1861   NaN  NaN     NaN  0.9  NaN NaN    NaN  27.0 NaN  NaN  ... -0.105361
# 1862   NaN  NaN     NaN  0.9  NaN NaN    NaN  30.0 NaN  NaN  ... -0.105361
# 1863   NaN  NaN     NaN  1.0  NaN NaN    NaN  37.0 NaN  NaN  ...  0.000000
# 1864   NaN  NaN     NaN  1.0  NaN NaN    NaN  48.0 NaN  NaN  ...  0.000000
#
#       lemp  lun  lprgnp      lcpi  lwg  lrwg  lm  lvel  lsp500
# year
# 1860   NaN  NaN     NaN  3.295837  NaN   NaN NaN   NaN     NaN
# 1861   NaN  NaN     NaN  3.295837  NaN   NaN NaN   NaN     NaN
# 1862   NaN  NaN     NaN  3.401197  NaN   NaN NaN   NaN     NaN
# 1863   NaN  NaN     NaN  3.610918  NaN   NaN NaN   NaN     NaN
# 1864   NaN  NaN     NaN  3.871201  NaN   NaN NaN   NaN     NaN
#
# [5 rows x 27 columns]

# %%
enders['granger'].r_short.plot()
# Out:
# <Axes: >

# %%
hyndman['rdatasets']['AirPassenger'].value.plot()
# Out:
# <Axes: >

# %% [markdown]
# # API

# %%
from tswidgets import sdt_get

df = sdt_get('143.3_NO_PR_2004_A_21,11.3_VMATC_2004_M_12,11.3_VMASD_2004_M_23,11.3_VIPAA_2004_M_5,11.3_ISOM_2004_M_39,11.3_P_2004_M_20,11.3_AGCS_2004_M_41') #678arlyc

# %%
df.head()
# Out:
#                emae_original  construccion  industria_manufacturera  \
# indice_tiempo
# 2004-01-01         92.627506     95.938047                91.454610
# 2004-02-01         90.186179     98.853388                89.424852
# 2004-03-01        101.883298    103.124529               101.426433
# 2004-04-01        102.567430     95.815492                98.437312
# 2004-05-01        109.877504     97.994567               100.353138
#
#                     pesca  agricultura_ganaderia_caza_silvicultura  \
# indice_tiempo
# 2004-01-01      42.547868                                65.995350
# 2004-02-01      62.440771                                64.926598
# 2004-03-01     174.084646                               110.666559
# 2004-04-01     153.877638                               150.065920
# 2004-05-01     132.357664                               209.388076
#
#                hoteles_restaurantes  comercio_mayorista_minorista_reparaciones
# indice_tiempo
# 2004-01-01               108.411682                                  92.065338
# 2004-02-01               103.448256                                  91.464718
# 2004-03-01               101.061842                                 109.127780
# 2004-04-01                93.242999                                  99.420141
# 2004-05-01                90.985260                                 100.532744
